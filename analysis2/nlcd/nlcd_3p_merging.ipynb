# %%
import pandas as pd
import json
import ast
import glob
import os

# %%
folder_path = 'Pneuf_NLCD_3P'

# List of CSV files
csv_files = glob.glob(os.path.join(folder_path,'NLCD_pixel_counts_3P_*.csv'))  # adjust path/pattern

# Load and combine
df_list = [pd.read_csv(f) for f in csv_files]
df = pd.concat(df_list, ignore_index=True).sort_values(by=['Year', 'UID']).reset_index(drop=True)

# %%
df
# Out:
#     Year  UID                                          histogram
# 0   2000  101  {31=189.0, 95=11092.580392156862, 11=4740.0, 5...
# 1   2000  102  {31=79.0, 11=931.0, 95=21751.4, 52=1052019.690...
# 2   2000  103  {31=50.96078431372549, 11=65028.55294117641, 9...
# 3   2001  101  {31=119.0, 95=11006.580392156862, 11=1429.0, 5...
# 4   2001  102  {31=70.0, 11=855.0, 95=21733.4, 52=1055236.670...
# ..   ...  ...                                                ...
# 70  2023  102  {52=1032486.8235294108, 95=23330.4, 11=1151.0,...
# 71  2023  103  {52=639767.4666666675, 95=29710.713725490197, ...
# 72  2024  101  {31=172.0, 11=4182.0, 95=10717.580392156862, 5...
# 73  2024  102  {31=67.0, 95=22920.4, 11=1128.0, 52=1026503.03...
# 74  2024  103  {31=260.0, 11=65420.67058823524, 95=29419.0588...
#
# [75 rows x 3 columns]

# %%
def parse_histogram(s):
    if pd.isna(s) or s.strip() == '':
        return {}
    s_fixed = s.replace('=', ':')
    return ast.literal_eval(s_fixed)

df['histogram_dict'] = df['histogram'].apply(parse_histogram)

# %%
df
# Out:
#     Year  UID                                          histogram  \
# 0   2000  101  {31=189.0, 95=11092.580392156862, 11=4740.0, 5...
# 1   2000  102  {31=79.0, 11=931.0, 95=21751.4, 52=1052019.690...
# 2   2000  103  {31=50.96078431372549, 11=65028.55294117641, 9...
# 3   2001  101  {31=119.0, 95=11006.580392156862, 11=1429.0, 5...
# 4   2001  102  {31=70.0, 11=855.0, 95=21733.4, 52=1055236.670...
# ..   ...  ...                                                ...
# 70  2023  102  {52=1032486.8235294108, 95=23330.4, 11=1151.0,...
# 71  2023  103  {52=639767.4666666675, 95=29710.713725490197, ...
# 72  2024  101  {31=172.0, 11=4182.0, 95=10717.580392156862, 5...
# 73  2024  102  {31=67.0, 95=22920.4, 11=1128.0, 52=1026503.03...
# 74  2024  103  {31=260.0, 11=65420.67058823524, 95=29419.0588...
#
#                                        histogram_dict
# 0   {31: 189.0, 95: 11092.580392156862, 11: 4740.0...
# 1   {31: 79.0, 11: 931.0, 95: 21751.4, 52: 1052019...
# 2   {31: 50.96078431372549, 11: 65028.55294117641,...
# 3   {31: 119.0, 95: 11006.580392156862, 11: 1429.0...
# 4   {31: 70.0, 11: 855.0, 95: 21733.4, 52: 1055236...
# ..                                                ...
# 70  {52: 1032486.8235294108, 95: 23330.4, 11: 1151...
# 71  {52: 639767.4666666675, 95: 29710.713725490197...
# 72  {31: 172.0, 11: 4182.0, 95: 10717.580392156862...
# 73  {31: 67.0, 95: 22920.4, 11: 1128.0, 52: 102650...
# 74  {31: 260.0, 11: 65420.67058823524, 95: 29419.0...
#
# [75 rows x 4 columns]

# %%
hist_df = pd.json_normalize(df['histogram_dict'])
hist_df.columns = [col for col in hist_df.columns]

# %%
land_cover_dict = {
    11: "Open Water",
    12: "Perennial Ice/Snow",
    21: "Developed, Open Space",
    22: "Developed, Low Intensity",
    23: "Developed, Medium Intensity",
    24: "Developed, High Intensity",
    31: "Barren Land",
    41: "Deciduous Forest",
    42: "Evergreen Forest",
    43: "Mixed Forest",
    52: "Shrub/Scrub",
    71: "Grassland/Herbaceous",
    81: "Pasture/Hay",
    82: "Cultivated Crops",
    90: "Woody Wetlands",
    95: "Emergent Herbaceous Wetlands"
}

# %%
def safe_rename(col):
    code = col
    if code in land_cover_dict:
        return f'{land_cover_dict[code].replace(" ", "_")}'
    else:
        return f'{code}'

hist_df.rename(columns=lambda c: safe_rename(c), inplace=True)

# %%
hist_df
# Out:
#     Barren_Land  Emergent_Herbaceous_Wetlands    Open_Water   Shrub/Scrub  \
# 0    189.000000                  11092.580392   4740.000000  9.924971e+05
# 1     79.000000                  21751.400000    931.000000  1.052020e+06
# 2     50.960784                  30151.058824  65028.552941  6.154461e+05
# 3    119.000000                  11006.580392   1429.000000  9.944837e+05
# 4     70.000000                  21733.400000    855.000000  1.055237e+06
# ..          ...                           ...           ...           ...
# 70    68.000000                  23330.400000   1151.000000  1.032487e+06
# 71   559.000000                  29710.713725  60496.078431  6.397675e+05
# 72   172.000000                  10717.580392   4182.000000  8.966345e+05
# 73    67.000000                  22920.400000   1128.000000  1.026503e+06
# 74   260.000000                  29419.058824  65420.670588  6.308360e+05
#
#     Grassland/Herbaceous  Developed,_High_Intensity  Woody_Wetlands  \
# 0            8921.796078                  27.000000     9761.203922
# 1           38246.658824                 107.000000     4694.654902
# 2          133696.196078                7041.109804    65919.768627
# 3           10714.505882                  28.000000     9739.203922
# 4           47975.996078                 107.000000     4695.654902
# ..                   ...                        ...             ...
# 70          24384.101961                 164.000000     4652.564706
# 71         135724.686275                7624.266667    69173.200000
# 72          17440.054902                  44.000000     9866.203922
# 73          26772.698039                 166.000000     4637.564706
# 74         140676.600000                7635.266667    65974.635294
#
#     Deciduous_Forest  Cultivated_Crops   Pasture/Hay  \
# 0       50182.027451     243807.356863  32517.360784
# 1       35274.807843     249644.843137  38390.015686
# 2       16739.525490     342720.521569   8381.482353
# 3       50149.027451     242342.356863  33850.360784
# 4       35353.807843     236265.650980  38301.015686
# ..               ...               ...           ...
# 70      46666.278431     231776.043137  37377.266667
# 71      23188.756863     276959.050980   9959.086275
# 72      60427.360784     269109.690196  33577.274510
# 73      48317.341176     229952.043137  38123.266667
# 74      24088.713725     276925.121569   9499.086275
#
#     Developed,_Medium_Intensity  Evergreen_Forest  Developed,_Low_Intensity  \
# 0                    539.000000     273596.745098               9680.694118
# 1                   3303.733333     196700.992157              20688.584314
# 2                  21356.956863      93580.188235              50385.658824
# 3                    538.000000     273394.439216               9697.694118
# 4                   3303.733333     197106.866667              20725.584314
# ..                          ...               ...                       ...
# 70                  4118.647059     227107.054902              26057.388235
# 71                 28579.796078     105654.388235              65802.662745
# 72                   796.901961     318962.745098              13761.066667
# 73                  4147.647059     230005.337255              26183.388235
# 74                 28781.796078     107145.525490              66272.364706
#
#     Developed,_Open_Space
# 0            19758.564706
# 1            28339.572549
# 2            28505.215686
# 3            19818.564706
# 4            28441.572549
# ..                    ...
# 70           30832.384314
# 71           25804.141176
# 72           21619.117647
# 73           31248.227451
# 74           26068.490196
#
# [75 rows x 14 columns]

# %%
# compute total pixels per row
total_pixels = hist_df.sum(axis=1).replace(0, 1)  # avoid division by zero

# compute percentage per crop
percent_df = hist_df.div(total_pixels, axis=0).multiply(100)

# merge counts + percentages
final_pix_df = pd.concat([df[['Year', 'UID']], hist_df], axis=1)
final_pcent_df = pd.concat([df[['Year', 'UID']], percent_df], axis=1)

# %%
total_pixels
# Out:
# 0     1.657310e+06
# 1     1.690172e+06
# 2     1.479003e+06
# 3     1.657310e+06
# 4     1.690172e+06
#           ...
# 70    1.690172e+06
# 71    1.479003e+06
# 72    1.657310e+06
# 73    1.690172e+06
# 74    1.479003e+06
# Length: 75, dtype: float64

# %%
final_pcent_df.to_csv('NLCD_3P_percent.csv', index=False)
final_pix_df.to_csv('NLCD_3P_pixel_count.csv', index=False)
