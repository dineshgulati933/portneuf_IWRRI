# %%
import geopandas as gpd

# %%
gdf = gpd.read_file('portneuf3/portneuf3.shp')

# %%
gdf
# Out:
#   states     Shape_Leng                    Name  \
# 0     ID       0.000000                    None
# 1   None  353198.797609  ID20250625201849366000
# 2   None       0.000000  ID20250625201849366000
#
#                                             geometry
# 0  POLYGON ((-112.08046 43.06812, -112.08058 43.0...
# 1  POLYGON ((-111.97985 42.47611, -111.97978 42.4...
# 2  MULTIPOLYGON (((-112.07294 42.54489, -112.0729...

# %%
gdf = gdf.drop(columns=['Name', 'Shape_Leng', 'states'])

# %%
gdf.insert(0, 'UID', [103,102,101])
gdf.insert(1, 'Name', ['Remaining', 'Below Topaz', ' Above Topaz'])

# %%
gdf = gdf.sort_values(by='UID')

# %%
gdf
# Out:
#    UID          Name                                           geometry
# 2  101   Above Topaz  MULTIPOLYGON (((-112.07294 42.54489, -112.0729...
# 1  102   Below Topaz  POLYGON ((-111.97985 42.47611, -111.97978 42.4...
# 0  103     Remaining  POLYGON ((-112.08046 43.06812, -112.08058 43.0...

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf.to_file('portneuf3_clean/portneuf3_clean.shp')

# %%
gdf[gdf['UID'] == 101].plot()
# Out:
# <Axes: >

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
at = gpd.read_file('Above_topaz/Above_topaz.shp')

# %%
at.plot()
# Out:
# <Axes: >

# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.26.4'
