# %%
import pandas as pd
import json
import ast
import glob
import os
from itables import show

# %%
folder_path = 'Pneuf_CDL'

# List of CSV files
csv_files = glob.glob(os.path.join(folder_path,'CDL_pixel_counts_HUC12_*.csv'))  # adjust path/pattern

# Load and combine
df_list = [pd.read_csv(f) for f in csv_files]
df = pd.concat(df_list, ignore_index=True)

# %%
with open('cdl_code_map.json', 'r') as f:
    cdl_code_map = json.load(f)

# %%
def parse_histogram(s):
    if pd.isna(s) or s.strip() == '':
        return {}
    s_fixed = s.replace('=', ':')
    return ast.literal_eval(s_fixed)

df['histogram_dict'] = df['histogram'].apply(parse_histogram)

# %%
hist_df = pd.json_normalize(df['histogram_dict'])
hist_df.columns = [col for col in hist_df.columns]

# %%
def safe_rename(col):
    code = str(col)
    if code in cdl_code_map:
        return f'{cdl_code_map[code].replace(" ", "_")}'
    else:
        return f'{code}'

hist_df.rename(columns=lambda c: safe_rename(c), inplace=True)

# %%
# hist_df.fillna(0, inplace=True)
# compute total pixels per row
total_pixels = hist_df.sum(axis=1).replace(0, 1)  # avoid division by zero

# compute percentage per crop
percent_df = hist_df.div(total_pixels, axis=0).multiply(100)

# merge counts + percentages
final_pix_df = pd.concat([df[['Year', 'huc12']], hist_df], axis=1)
final_pcent_df = pd.concat([df[['Year', 'huc12']], percent_df], axis=1)

# %%
final_pcent_df.sort_values('Year')
# Out:
#      Year         huc12  Safflower  Open_Water  Other_Hay/Non_Alfalfa  \
# 873  2005  170402080404        NaN         NaN                    NaN
# 847  2005  170402080502        NaN         NaN                    NaN
# 846  2005  170402080501        NaN         NaN                    NaN
# 845  2005  170402080206        NaN         NaN                    NaN
# 844  2005  170402080103        NaN         NaN                    NaN
# ..    ...           ...        ...         ...                    ...
# 718  2023  170402080203   0.031864    0.002655               2.867771
# 717  2023  170402080201   0.074855    0.003119               0.166374
# 716  2023  170402080306   2.037586    0.000401               2.538664
# 714  2023  170402080604   0.013496         NaN               0.022280
# 690  2023  170402080608   0.044237   29.238000               0.779233
#
#      Deciduous_Forest      Oats  Fallow/Idle_Cropland  Sod/Grass_Seed  \
# 873               NaN  0.000851             11.435455             NaN
# 847               NaN       NaN              9.418411             NaN
# 846               NaN  0.002152             16.072317             NaN
# 845               NaN  0.012949              5.411643             NaN
# 844               NaN       NaN              8.875553             NaN
# ..                ...       ...                   ...             ...
# 718          2.105365  0.015932              1.592873             NaN
# 717          2.760724  0.030290              4.263626        0.038987
# 716          0.243081  0.111769              2.184821        0.009512
# 714          0.001311       NaN              0.137537             NaN
# 690               NaN  0.030228              1.536455        0.026794
#
#      Winter_Wheat  ...  Buckwheat  Dbl_Crop_Barley/Corn  Radishes  Cherries  \
# 873      1.027731  ...        NaN                   NaN       NaN       NaN
# 847      4.378855  ...        NaN                   NaN       NaN       NaN
# 846      0.920079  ...        NaN                   NaN       NaN       NaN
# 845      0.468678  ...        NaN                   NaN       NaN       NaN
# 844      0.235431  ...        NaN                   NaN       NaN       NaN
# ..            ...  ...        ...                   ...       ...       ...
# 718      1.627820  ...        NaN                   NaN       NaN       NaN
# 717      0.547876  ...        NaN                   NaN       NaN       NaN
# 716      3.268955  ...        NaN                   NaN       NaN       NaN
# 714     11.049987  ...        NaN                   NaN       NaN       NaN
# 690      9.509863  ...        NaN                   NaN       NaN       NaN
#
#      Camelina  Soybeans  Nonag/Undefined  Water  Developed  Clouds/No_Data
# 873       NaN       NaN         0.146414    NaN   1.745545             NaN
# 847       NaN       NaN         0.078423    NaN   1.584811             NaN
# 846       NaN       NaN         0.069261    NaN   0.740752             NaN
# 845       NaN       NaN         0.136264    NaN   1.126078        0.023544
# 844       NaN       NaN         0.016684    NaN   0.181320             NaN
# ..        ...       ...              ...    ...        ...             ...
# 718       NaN       NaN              NaN    NaN        NaN             NaN
# 717       NaN       NaN              NaN    NaN        NaN             NaN
# 716       NaN       NaN              NaN    NaN        NaN             NaN
# 714       NaN       NaN              NaN    NaN        NaN             NaN
# 690       NaN       NaN              NaN    NaN        NaN             NaN
#
# [874 rows x 68 columns]

# %%
final_pcent_df.sort_values('Year', inplace=True)
final_pix_df.sort_values('Year', inplace=True)

# %%
# final_pcent_df.to_csv('CDL_percent.csv', index=False)
# final_pix_df.to_csv('CDL_pixel_count.csv', index=False)
